# %%
import keras
from keras.datasets import cifar10
# from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop
# from keras.optimizers import Adam
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# 由於 DNN 只能輸入一維的資料，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32 * 32 * 3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, 
                    y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0803 01:10:59.938249 10556 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0803 01:10:59.953257 10556 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0803 01:10:59.956245 10556 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0803 01:10:59.973238 10556 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0803 01:10:59.982248 10556 deprecation.py:506] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0803 01:11:00.060222 10556 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0803 01:11:00.068225 10556 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0803 01:11:00.167189 10556 deprecation.py:323] From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 4s 80us/step - loss: 2.2612 - acc: 0.2440 - val_loss: 1.8811 - val_acc: 0.3140
# Epoch 2/10
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.8758 - acc: 0.3192 - val_loss: 1.7479 - val_acc: 0.3818
# Epoch 3/10
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.7966 - acc: 0.3517 - val_loss: 1.7433 - val_acc: 0.3715
# Epoch 4/10
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.7417 - acc: 0.3730 - val_loss: 1.6466 - val_acc: 0.4179
# Epoch 5/10
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.7070 - acc: 0.3885 - val_loss: 1.6295 - val_acc: 0.4232
# Epoch 6/10
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.6793 - acc: 0.3951 - val_loss: 1.6475 - val_acc: 0.4096
# Epoch 7/10
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.6567 - acc: 0.4064 - val_loss: 1.6915 - val_acc: 0.3888
# Epoch 8/10
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.6392 - acc: 0.4141 - val_loss: 1.5831 - val_acc: 0.4406
# Epoch 9/10
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.6185 - acc: 0.4225 - val_loss: 1.6076 - val_acc: 0.4289
# Epoch 10/10
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.6109 - acc: 0.4247 - val_loss: 1.5796 - val_acc: 0.4484
# Test loss: 1.5795557327270509
# Test accuracy: 0.4484

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# W0803 02:20:49.954176 10556 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 10s 199us/step - loss: 1.7541 - acc: 0.3626 - val_loss: 1.4527 - val_acc: 0.4838
# Epoch 2/10
# 50000/50000 [==============================] - 9s 174us/step - loss: 1.3300 - acc: 0.5274 - val_loss: 1.2349 - val_acc: 0.5633
# Epoch 3/10
# 50000/50000 [==============================] - 9s 182us/step - loss: 1.1247 - acc: 0.6066 - val_loss: 0.9627 - val_acc: 0.6628
# Epoch 4/10
# 50000/50000 [==============================] - 8s 165us/step - loss: 0.9918 - acc: 0.6532 - val_loss: 0.9136 - val_acc: 0.6744
# Epoch 5/10
# 50000/50000 [==============================] - 8s 170us/step - loss: 0.9029 - acc: 0.6857 - val_loss: 0.7827 - val_acc: 0.7253
# Epoch 6/10
# 50000/50000 [==============================] - 9s 177us/step - loss: 0.8305 - acc: 0.7114 - val_loss: 0.8160 - val_acc: 0.7174
# Epoch 7/10
# 50000/50000 [==============================] - 9s 172us/step - loss: 0.7715 - acc: 0.7325 - val_loss: 0.7472 - val_acc: 0.7398
# Epoch 8/10
# 50000/50000 [==============================] - 9s 171us/step - loss: 0.7328 - acc: 0.7457 - val_loss: 0.7074 - val_acc: 0.7575
# Epoch 9/10
# 50000/50000 [==============================] - 9s 170us/step - loss: 0.6936 - acc: 0.7567 - val_loss: 0.7484 - val_acc: 0.7406
# Epoch 10/10
# 50000/50000 [==============================] - 9s 171us/step - loss: 0.6640 - acc: 0.7689 - val_loss: 0.7149 - val_acc: 0.7630
# Test loss: 0.7149357161998748
# Test accuracy: 0.763

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
# > 可以調整的有: Conv2D 的層數、filters 數量、stride 大小、學習率的大小、優化器的選擇、Dropout 的比率等等。其中 Conv2D 的層數與優化器的選擇對結果會有較明顯的影響。
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?
# > DNN較多，CNN 在做卷機時，透過較小的參數量就可以逐步縮小影像大小，讓最後再接上 Dense 層時不要有過多的參數。

# %% [markdown]
# ## 試著將 Conv2D 更換為 SeparableConv2D

# %%
from keras.layers import SeparableConv2D

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


model = Sequential()
model.add(SeparableConv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(SeparableConv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(SeparableConv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(SeparableConv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d_1 (Separabl (None, 32, 32, 32)        155
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 30, 30, 32)        1344
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 15, 15, 64)        2400
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# separable_conv2d_4 (Separabl (None, 13, 13, 64)        4736
# _________________________________________________________________
# activation_10 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_12 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,193,925
# Trainable params: 1,193,925
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 19s 379us/step - loss: 1.9561 - acc: 0.2808 - val_loss: 1.7138 - val_acc: 0.3696
# Epoch 2/10
# 50000/50000 [==============================] - 18s 356us/step - loss: 1.6725 - acc: 0.3946 - val_loss: 1.5165 - val_acc: 0.4572
# Epoch 3/10
# 50000/50000 [==============================] - 18s 356us/step - loss: 1.5404 - acc: 0.4461 - val_loss: 1.4383 - val_acc: 0.4874
# Epoch 4/10
# 50000/50000 [==============================] - 17s 350us/step - loss: 1.4537 - acc: 0.4769 - val_loss: 1.3409 - val_acc: 0.5155
# Epoch 5/10
# 50000/50000 [==============================] - 18s 352us/step - loss: 1.3889 - acc: 0.5014 - val_loss: 1.3256 - val_acc: 0.5265
# Epoch 6/10
# 50000/50000 [==============================] - 18s 353us/step - loss: 1.3222 - acc: 0.5263 - val_loss: 1.2731 - val_acc: 0.5510
# Epoch 7/10
# 50000/50000 [==============================] - 18s 351us/step - loss: 1.2610 - acc: 0.5524 - val_loss: 1.1645 - val_acc: 0.5866
# Epoch 8/10
# 50000/50000 [==============================] - 18s 351us/step - loss: 1.2000 - acc: 0.5738 - val_loss: 1.1396 - val_acc: 0.5973
# Epoch 9/10
# 50000/50000 [==============================] - 18s 356us/step - loss: 1.1526 - acc: 0.5914 - val_loss: 1.0987 - val_acc: 0.6120
# Epoch 10/10
# 50000/50000 [==============================] - 18s 358us/step - loss: 1.1079 - acc: 0.6071 - val_loss: 1.0722 - val_acc: 0.6272
# Test loss: 1.0721975650787354
# Test accuracy: 0.6272

# %% [markdown]
# ## 減少 SeparableConv2D 層數 並將優化器由RMSprop換為Adam

# %%
from keras.optimizers import Adam

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


model = Sequential()
model.add(SeparableConv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(SeparableConv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d_5 (Separabl (None, 32, 32, 32)        155
# _________________________________________________________________
# activation_13 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# separable_conv2d_6 (Separabl (None, 16, 16, 64)        2400
# _________________________________________________________________
# activation_14 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# activation_15 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_16 (Activation)   (None, 10)                0
# =================================================================
# Total params: 2,105,349
# Trainable params: 2,105,349
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 7s 142us/step - loss: 1.7541 - acc: 0.3585 - val_loss: 1.4813 - val_acc: 0.4696
# Epoch 2/10
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.4695 - acc: 0.4707 - val_loss: 1.3383 - val_acc: 0.5269
# Epoch 3/10
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.3563 - acc: 0.5139 - val_loss: 1.2308 - val_acc: 0.5610
# Epoch 4/10
# 50000/50000 [==============================] - 6s 129us/step - loss: 1.2830 - acc: 0.5413 - val_loss: 1.1898 - val_acc: 0.5868
# Epoch 5/10
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.2289 - acc: 0.5641 - val_loss: 1.1267 - val_acc: 0.6024
# Epoch 6/10
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.1845 - acc: 0.5806 - val_loss: 1.0976 - val_acc: 0.6138
# Epoch 7/10
# 50000/50000 [==============================] - 7s 130us/step - loss: 1.1416 - acc: 0.5963 - val_loss: 1.0688 - val_acc: 0.6278
# Epoch 8/10
# 50000/50000 [==============================] - 7s 130us/step - loss: 1.1141 - acc: 0.6042 - val_loss: 1.0431 - val_acc: 0.6356
# Epoch 9/10
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.0819 - acc: 0.6177 - val_loss: 1.0301 - val_acc: 0.6352
# Epoch 10/10
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.0543 - acc: 0.6248 - val_loss: 0.9927 - val_acc: 0.6502
# Test loss: 0.9927274871826172
# Test accuracy: 0.6502

# %% [markdown]
# ## SeparableConv2D維持4層，優化器改使用Adam

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


model = Sequential()
model.add(SeparableConv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(SeparableConv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(SeparableConv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(SeparableConv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d_7 (Separabl (None, 32, 32, 32)        155
# _________________________________________________________________
# activation_17 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# separable_conv2d_8 (Separabl (None, 30, 30, 32)        1344
# _________________________________________________________________
# activation_18 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# separable_conv2d_9 (Separabl (None, 15, 15, 64)        2400
# _________________________________________________________________
# activation_19 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# separable_conv2d_10 (Separab (None, 13, 13, 64)        4736
# _________________________________________________________________
# activation_20 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_21 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_22 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,193,925
# Trainable params: 1,193,925
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 20s 406us/step - loss: 1.9611 - acc: 0.2739 - val_loss: 1.5857 - val_acc: 0.4326
# Epoch 2/10
# 50000/50000 [==============================] - 19s 383us/step - loss: 1.5490 - acc: 0.4444 - val_loss: 1.4094 - val_acc: 0.4935
# Epoch 3/10
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.4244 - acc: 0.4874 - val_loss: 1.2873 - val_acc: 0.5325
# Epoch 4/10
# 50000/50000 [==============================] - 19s 384us/step - loss: 1.3355 - acc: 0.5217 - val_loss: 1.2285 - val_acc: 0.5572
# Epoch 5/10
# 50000/50000 [==============================] - 19s 386us/step - loss: 1.2636 - acc: 0.5483 - val_loss: 1.1695 - val_acc: 0.5812
# Epoch 6/10
# 50000/50000 [==============================] - 19s 384us/step - loss: 1.2125 - acc: 0.5694 - val_loss: 1.1125 - val_acc: 0.6102
# Epoch 7/10
# 50000/50000 [==============================] - 19s 383us/step - loss: 1.1642 - acc: 0.5883 - val_loss: 1.0835 - val_acc: 0.6165
# Epoch 8/10
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.1208 - acc: 0.6056 - val_loss: 1.0513 - val_acc: 0.6331
# Epoch 9/10
# 50000/50000 [==============================] - 19s 380us/step - loss: 1.0812 - acc: 0.6182 - val_loss: 1.0061 - val_acc: 0.6468
# Epoch 10/10
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.0482 - acc: 0.6288 - val_loss: 0.9849 - val_acc: 0.6575
# Test loss: 0.9848806495666504
# Test accuracy: 0.6575

# %% [markdown]
# ## Conv2D維持4層，優化器使用Adam

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_23 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_24 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_25 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_26 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_27 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_28 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 9s 183us/step - loss: 1.6073 - acc: 0.4111 - val_loss: 1.2466 - val_acc: 0.5468
# Epoch 2/10
# 50000/50000 [==============================] - 9s 171us/step - loss: 1.2205 - acc: 0.5641 - val_loss: 1.0604 - val_acc: 0.6254
# Epoch 3/10
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.0635 - acc: 0.6250 - val_loss: 0.9740 - val_acc: 0.6557
# Epoch 4/10
# 50000/50000 [==============================] - 9s 173us/step - loss: 0.9513 - acc: 0.6652 - val_loss: 0.8468 - val_acc: 0.7036
# Epoch 5/10
# 50000/50000 [==============================] - 8s 168us/step - loss: 0.8658 - acc: 0.6972 - val_loss: 0.7723 - val_acc: 0.7294
# Epoch 6/10
# 50000/50000 [==============================] - 8s 166us/step - loss: 0.8026 - acc: 0.7199 - val_loss: 0.7336 - val_acc: 0.7453
# Epoch 7/10
# 50000/50000 [==============================] - 8s 167us/step - loss: 0.7460 - acc: 0.7390 - val_loss: 0.7004 - val_acc: 0.7585
# Epoch 8/10
# 50000/50000 [==============================] - 9s 175us/step - loss: 0.7024 - acc: 0.7530 - val_loss: 0.6972 - val_acc: 0.7612
# Epoch 9/10
# 50000/50000 [==============================] - 9s 171us/step - loss: 0.6709 - acc: 0.7608 - val_loss: 0.6931 - val_acc: 0.7616
# Epoch 10/10
# 50000/50000 [==============================] - 8s 168us/step - loss: 0.6302 - acc: 0.7778 - val_loss: 0.6684 - val_acc: 0.7665
# Test loss: 0.6684072617530823
# Test accuracy: 0.7665
